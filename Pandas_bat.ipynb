# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
h=['c++','java','python','javascript']

# %%
pd.Series(h)
# Out:
# 0           c++
# 1          java
# 2        python
# 3    javascript
# dtype: object

# %%
book_title = pd.Series(h)

# %%
book_title
# Out:
# 0           c++
# 1          java
# 2        python
# 3    javascript
# dtype: object

# %%
type(book_title)
# Out:
# pandas.core.series.Series

# %%
book_title[3]
# Out:
# 'javascript'

# %%
book_title[2]
# Out:
# 'python'

# %%
book_title[0]
# Out:
# 'c++'

# %%
book_title
# Out:
# 0           c++
# 1          java
# 2        python
# 3    javascript
# dtype: object

# %%
book_title.index = ['a','b','c','d']

# %%
book_title
# Out:
# a           c++
# b          java
# c        python
# d    javascript
# dtype: object

# %%
book_title['c']
# Out:
# 'python'

# %%
import numpy as np

# %%
arr=np.random.randint(10,100,size=(6,4))

# %%
arr
# Out:
# array([[87, 20, 72, 50],
#        [21, 65, 70, 66],
#        [26, 92, 36, 65],
#        [34, 72, 82, 66],
#        [64, 78, 32, 49],
#        [72, 19, 87, 34]])

# %%
df=pd.DataFrame(arr)

# %%
df
# Out:
#     0   1   2   3
# 0  87  20  72  50
# 1  21  65  70  66
# 2  26  92  36  65
# 3  34  72  82  66
# 4  64  78  32  49
# 5  72  19  87  34

# %%
arr=np.random.randint(100,1000,size=(7,5))

# %%
arr
# Out:
# array([[417, 954, 740, 799, 293],
#        [965, 509, 709, 194, 431],
#        [482, 688, 466, 550, 952],
#        [976, 488, 773, 599, 597],
#        [122, 293, 827, 419, 469],
#        [214, 394, 705, 544, 518],
#        [818, 667, 206, 744, 876]])

# %%
df=pd.DataFrame(arr)

# %%
df
# Out:
#      0    1    2    3    4
# 0  417  954  740  799  293
# 1  965  509  709  194  431
# 2  482  688  466  550  952
# 3  976  488  773  599  597
# 4  122  293  827  419  469
# 5  214  394  705  544  518
# 6  818  667  206  744  876

# %%
df
# Out:
#      0    1    2    3    4
# 0  417  954  740  799  293
# 1  965  509  709  194  431
# 2  482  688  466  550  952
# 3  976  488  773  599  597
# 4  122  293  827  419  469
# 5  214  394  705  544  518
# 6  818  667  206  744  876

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns = ['P','Q','R','S','T']

# %%
df
# Out:
#      P    Q    R    S    T
# 0  417  954  740  799  293
# 1  965  509  709  194  431
# 2  482  688  466  550  952
# 3  976  488  773  599  597
# 4  122  293  827  419  469
# 5  214  394  705  544  518
# 6  818  667  206  744  876

# %%
df['Q']
# Out:
# 0    954
# 1    509
# 2    688
# 3    488
# 4    293
# 5    394
# 6    667
# Name: Q, dtype: int32

# %%
df['R']
# Out:
# 0    740
# 1    709
# 2    466
# 3    773
# 4    827
# 5    705
# 6    206
# Name: R, dtype: int32

# %%
df[['S','R','Q']]
# Out:
#      S    R    Q
# 0  799  740  954
# 1  194  709  509
# 2  550  466  688
# 3  599  773  488
# 4  419  827  293
# 5  544  705  394
# 6  744  206  667

# %%
df
# Out:
#      P    Q    R    S    T
# 0  417  954  740  799  293
# 1  965  509  709  194  431
# 2  482  688  466  550  952
# 3  976  488  773  599  597
# 4  122  293  827  419  469
# 5  214  394  705  544  518
# 6  818  667  206  744  876

# %%
df.head()
# Out:
#      P    Q    R    S    T
# 0  417  954  740  799  293
# 1  965  509  709  194  431
# 2  482  688  466  550  952
# 3  976  488  773  599  597
# 4  122  293  827  419  469

# %%
df.head(3)
# Out:
#      P    Q    R    S    T
# 0  417  954  740  799  293
# 1  965  509  709  194  431
# 2  482  688  466  550  952

# %%
df.tail(2)
# Out:
#      P    Q    R    S    T
# 5  214  394  705  544  518
# 6  818  667  206  744  876

# %%
df
# Out:
#      P    Q    R    S    T
# 0  417  954  740  799  293
# 1  965  509  709  194  431
# 2  482  688  466  550  952
# 3  976  488  773  599  597
# 4  122  293  827  419  469
# 5  214  394  705  544  518
# 6  818  667  206  744  876

# %%
df.sample()
# Out:
#      P    Q    R    S    T
# 4  122  293  827  419  469

# %%
df
# Out:
#      P    Q    R    S    T
# 0  417  954  740  799  293
# 1  965  509  709  194  431
# 2  482  688  466  550  952
# 3  976  488  773  599  597
# 4  122  293  827  419  469
# 5  214  394  705  544  518
# 6  818  667  206  744  876

# %%
df.shape
# Out:
# (7, 5)

# %%
df
# Out:
#      P    Q    R    S    T
# 0  417  954  740  799  293
# 1  965  509  709  194  431
# 2  482  688  466  550  952
# 3  976  488  773  599  597
# 4  122  293  827  419  469
# 5  214  394  705  544  518
# 6  818  667  206  744  876

# %%
df['U'] = df['P'] + df['Q']

# %%
df
# Out:
#      P    Q    R    S    T     U
# 0  417  954  740  799  293  1371
# 1  965  509  709  194  431  1474
# 2  482  688  466  550  952  1170
# 3  976  488  773  599  597  1464
# 4  122  293  827  419  469   415
# 5  214  394  705  544  518   608
# 6  818  667  206  744  876  1485

# %%
df['V'] = df['Q'] * df['R']

# %%
df
# Out:
#      P    Q    R    S    T     U       V
# 0  417  954  740  799  293  1371  705960
# 1  965  509  709  194  431  1474  360881
# 2  482  688  466  550  952  1170  320608
# 3  976  488  773  599  597  1464  377224
# 4  122  293  827  419  469   415  242311
# 5  214  394  705  544  518   608  277770
# 6  818  667  206  744  876  1485  137402

# %%
df = df.drop('R',axis=1)

# %%
df
# Out:
#      P    Q    S    T     U       V
# 0  417  954  799  293  1371  705960
# 1  965  509  194  431  1474  360881
# 2  482  688  550  952  1170  320608
# 3  976  488  599  597  1464  377224
# 4  122  293  419  469   415  242311
# 5  214  394  544  518   608  277770
# 6  818  667  744  876  1485  137402

# %%
df.drop('U',axis=1,inplace=True)

# %%
df
# Out:
#      P    Q    S    T       V
# 0  417  954  799  293  705960
# 1  965  509  194  431  360881
# 2  482  688  550  952  320608
# 3  976  488  599  597  377224
# 4  122  293  419  469  242311
# 5  214  394  544  518  277770
# 6  818  667  744  876  137402

# %%
df.index = "a b c d e f g".split()

# %%
df
# Out:
#      P    Q    S    T       V
# a  417  954  799  293  705960
# b  965  509  194  431  360881
# c  482  688  550  952  320608
# d  976  488  599  597  377224
# e  122  293  419  469  242311
# f  214  394  544  518  277770
# g  818  667  744  876  137402

# %%
df.loc['a']
# Out:
# P       417
# Q       954
# S       799
# T       293
# V    705960
# Name: a, dtype: int32

# %%
df.iloc[0]
# Out:
# P       417
# Q       954
# S       799
# T       293
# V    705960
# Name: a, dtype: int32

# %%
df
# Out:
#      P    Q    S    T       V
# a  417  954  799  293  705960
# b  965  509  194  431  360881
# c  482  688  550  952  320608
# d  976  488  599  597  377224
# e  122  293  419  469  242311
# f  214  394  544  518  277770
# g  818  667  744  876  137402

# %%
df.iloc[3:,1:]
# Out:
#      Q    S    T       V
# d  488  599  597  377224
# e  293  419  469  242311
# f  394  544  518  277770
# g  667  744  876  137402

# %%
df.iloc[1:4,1:4]
# Out:
#      Q    S    T
# b  509  194  431
# c  688  550  952
# d  488  599  597

# %%
#masking

# %%
df
# Out:
#      P    Q    S    T       V
# a  417  954  799  293  705960
# b  965  509  194  431  360881
# c  482  688  550  952  320608
# d  976  488  599  597  377224
# e  122  293  419  469  242311
# f  214  394  544  518  277770
# g  818  667  744  876  137402

# %%
df[df['Q']>500]
# Out:
#      P    Q    S    T       V
# a  417  954  799  293  705960
# b  965  509  194  431  360881
# c  482  688  550  952  320608
# g  818  667  744  876  137402

# %%
df
# Out:
#      P    Q    S    T       V
# a  417  954  799  293  705960
# b  965  509  194  431  360881
# c  482  688  550  952  320608
# d  976  488  599  597  377224
# e  122  293  419  469  242311
# f  214  394  544  518  277770
# g  818  667  744  876  137402

# %%
df[(df>300) & (df>500)]
# Out:
#        P      Q      S      T       V
# a    NaN  954.0  799.0    NaN  705960
# b  965.0  509.0    NaN    NaN  360881
# c    NaN  688.0  550.0  952.0  320608
# d  976.0    NaN  599.0  597.0  377224
# e    NaN    NaN    NaN    NaN  242311
# f    NaN    NaN  544.0  518.0  277770
# g  818.0  667.0  744.0  876.0  137402

# %%
df[(df>300) | (df<500)]
# Out:
#      P    Q    S    T       V
# a  417  954  799  293  705960
# b  965  509  194  431  360881
# c  482  688  550  952  320608
# d  976  488  599  597  377224
# e  122  293  419  469  242311
# f  214  394  544  518  277770
# g  818  667  744  876  137402

# %%
#pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      P    Q    S    T       V
# a  417  954  799  293  705960
# b  965  509  194  431  360881
# c  482  688  550  952  320608
# d  976  488  599  597  377224
# e  122  293  419  469  242311
# f  214  394  544  518  277770
# g  818  667  744  876  137402

# %%
df.head()
# Out:
#      P    Q    S    T       V
# a  417  954  799  293  705960
# b  965  509  194  431  360881
# c  482  688  550  952  320608
# d  976  488  599  597  377224
# e  122  293  419  469  242311

# %%
df.tail()
# Out:
#      P    Q    S    T       V
# c  482  688  550  952  320608
# d  976  488  599  597  377224
# e  122  293  419  469  242311
# f  214  394  544  518  277770
# g  818  667  744  876  137402

# %%
df.shape
# Out:
# (7, 5)

# %%
df.columns
# Out:
# Index(['P', 'Q', 'S', 'T', 'V'], dtype='object')

# %%
df.dtypes
# Out:
# P    int32
# Q    int32
# S    int32
# T    int32
# V    int32
# dtype: object

# %%
import pandas as pd

# %%
df=pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.tail(6)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.species
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.species.nunique()
# Out:
# 3

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.species
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df[df.species=='virginica']
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
df[df.species =='versicolor']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.species.value_counts()['setosa']
# Out:
# 50

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.sepal_length.min()
# Out:
# 4.3

# %%
df.petal_length.max()
# Out:
# 6.9

# %%
df.sepal_width.mean()
# Out:
# 3.0540000000000003

# %%
df.petal_width.sum()
# Out:
# 179.8

# %%
df.sepal_length.count()
# Out:
# 150

# %%
df.sepal_length.std()
# Out:
# 0.8280661279778629

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df=df.sort_values(by='sepal_length', ascending=False)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.sort_values(by=["sepal_length","sepal_width"],ascending=[True,False],inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
df.apply(len)
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
df.species.apply(len)
# Out:
# 13     6
# 42     6
# 38     6
# 8      6
# 41     6
#       ..
# 117    9
# 135    9
# 122    9
# 118    9
# 131    9
# Name: species, Length: 150, dtype: int64

# %%
df.apply(lambda x:x+x)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width             species
# 13            8.6          6.0           2.2          0.2        setosasetosa
# 42            8.8          6.4           2.6          0.4        setosasetosa
# 38            8.8          6.0           2.6          0.4        setosasetosa
# 8             8.8          5.8           2.8          0.4        setosasetosa
# 41            9.0          4.6           2.6          0.6        setosasetosa
# ..            ...          ...           ...          ...                 ...
# 117          15.4          7.6          13.4          4.4  virginicavirginica
# 135          15.4          6.0          12.2          4.6  virginicavirginica
# 122          15.4          5.6          13.4          4.0  virginicavirginica
# 118          15.4          5.2          13.8          4.6  virginicavirginica
# 131          15.8          7.6          12.8          4.0  virginicavirginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
df[df.species == 'setosa']['sepal_length'].min()
# Out:
# 4.3

# %%
df[df.species == 'versicolor']['petal_width'].mean()
# Out:
# 1.3260000000000003

# %%
df.aggregate('min')
# Out:
# sepal_length       4.3
# sepal_width        2.0
# petal_length       1.0
# petal_width        0.1
# species         setosa
# dtype: object

# %%
import warnings
warnings.filterwarnings('ignore')
df.aggregate(['min','max','mean','median'])
# Out:
#         sepal_length  sepal_width  petal_length  petal_width    species
# min         4.300000        2.000      1.000000     0.100000     setosa
# max         7.900000        4.400      6.900000     2.500000  virginica
# mean        5.843333        3.054      3.758667     1.198667        NaN
# median      5.800000        3.000      4.350000     1.300000        NaN

# %%
obj = df.groupby('species')

# %%
obj.mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
obj.min()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               4.3          2.3           1.0          0.1
# versicolor           4.9          2.0           3.0          1.0
# virginica            4.9          2.2           4.5          1.4

# %%
obj.max()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.8          4.4           1.9          0.6
# versicolor           7.0          3.4           5.1          1.8
# virginica            7.9          3.8           6.9          2.5

# %%
obj.std()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa          0.352490     0.381024      0.173511     0.107210
# versicolor      0.516171     0.313798      0.469911     0.197753
# virginica       0.635880     0.322497      0.551895     0.274650

# %%
obj.describe().T
# Out:
# species                setosa  versicolor  virginica
# sepal_length count  50.000000   50.000000  50.000000
#              mean    5.006000    5.936000   6.588000
#              std     0.352490    0.516171   0.635880
#              min     4.300000    4.900000   4.900000
#              25%     4.800000    5.600000   6.225000
#              50%     5.000000    5.900000   6.500000
#              75%     5.200000    6.300000   6.900000
#              max     5.800000    7.000000   7.900000
# sepal_width  count  50.000000   50.000000  50.000000
#              mean    3.418000    2.770000   2.974000
#              std     0.381024    0.313798   0.322497
#              min     2.300000    2.000000   2.200000
#              25%     3.125000    2.525000   2.800000
#              50%     3.400000    2.800000   3.000000
#              75%     3.675000    3.000000   3.175000
#              max     4.400000    3.400000   3.800000
# petal_length count  50.000000   50.000000  50.000000
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2E69-7AEC
#
#  Directory of C:\Users\aa
#
# 03-07-2023  13:54    <DIR>          .
# 03-07-2023  13:54    <DIR>          ..
# 26-06-2023  12:50    <DIR>          .idlerc
# 30-06-2023  14:55    <DIR>          .ipynb_checkpoints
# 14-06-2023  23:16    <DIR>          .ipython
# 14-06-2023  23:15    <DIR>          .jupyter
# 26-06-2023  14:35    <DIR>          .matplotlib
# 27-06-2023  00:57    <DIR>          .vscode
# 14-06-2023  02:35    <DIR>          3D Objects
# 14-06-2023  02:35    <DIR>          Contacts
# 03-07-2023  00:56    <DIR>          Desktop
# 01-07-2023  01:13    <DIR>          Documents
# 02-07-2023  00:02    <DIR>          Downloads
# 14-06-2023  02:35    <DIR>          Favorites
# 14-06-2023  02:35    <DIR>          Links
# 14-06-2023  02:35    <DIR>          Music
# 01-07-2023  14:57             4,019 my_data_bat.csv
# 14-06-2023  02:39    <DIR>          OneDrive
# ...

# %%
df = pd.read_csv('iris_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 df = pd.read_csv('iris_data.csv')
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\aa\Desktop\bat\iris_data.csv')

# %%
df

# %%
df

# %%
df.isnull().sum()

# %%
import numpy as np

# %%
sanjay = np.random.randint(10,100,20)
df.sepal_length[sanjay] = np.nan

# %%
df.isnull().sum()

# %%
df.petal_length[sanjay] = np.nan

# %%
df.isnull().sum()

# %%
df.shape

# %%
df.dropna()

# %%
df.dropna(inplace=True)

# %%
df

# %%
df

# %%
df.shape

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\aa\Desktop\bat\iris_data.csv')

# %%
df

# %%
df.isnull().sum()

# %%
import numpy as np

# %%
g = np.random.randint(0,150,10)
h = np.random.randint(0,150,20)

# %%
df.petal_length[g] = np.nan
df.sepal_width[h] = np.nan

# %%
df.isnull().sum()

# %%
df

# %%
# df.dropna()

# %%
df.isnull().sum()

# %%
df.sepal_width.fillna(value="data")[:50]

# %%
df

# %%
round(df.sepal_width.mean(),ndigits=1)

# %%
df.sepal_width.fillna(value=round(df.sepal_width.mean(),ndigits=1),inplace=True)

# %%
df

# %%
df.isnull().sum()

# %%
df.petal_length.fillna(value=df.petal_length.median(),inplace=True)

# %%
df

# %%
df.isnull().sum()

# %%
df

# %%
new_df = pd.DataFrame(np.random.randint(0,7, (10,4)))

# %%
new_df

# %%
df

# %%
df.columns

# %%
new_df.columns

# %%
new_df['species'] = 'new species'

# %%
new_df

# %%
new_df.columns = df.columns

# %%
new_df

# %%
pd.concat((df,new_df),axis=0 )

# %%
new_df

# %%
#merging

# %%
df1 = pd.DataFrame({'S_name':['Mohit','Jatin','Prateek','Mohit'],'CGPA':[2,4,5,3]})

# %%
df1

# %%
df2 = pd.DataFrame({'T_name':['Mohit','Jatin','Prateek','Mohit'],'CGPA':[3,6,8,9]})

# %%
df2

# %%
df1

# %%
df2

# %%
df1.merge(df2)

# %%
df1.merge(df2, how='left')

# %%
df1.merge(df2, how='right')

# %%
df1.merge(df2, how='outer')

# %%
df.to_csv('my_data_bat.csv' ,index=False)

# %%
df=pd.read_csv('my_data_bat.csv')
